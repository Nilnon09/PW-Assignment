# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %%
# Estimation Statistics involves inferring the value of a population parameter based on sample data.

# Point Estimate: A single value estimate of a parameter (e.g., sample mean as estimate of population mean).

# Interval Estimate: A range (confidence interval) where the parameter is expected to lie with a certain probability.

# %% [markdown]
# Q2: Python function to estimate the population mean using sample data

# %%
def estimate_population_mean(sample_mean, std_dev, sample_size):
    return sample_mean  # The point estimate is the sample mean

# %% [markdown]
# Q3: What is Hypothesis Testing?

# %%
# Hypothesis Testing is a statistical method for testing an assumption about a population parameter.

# Used for: Making decisions or inferences about populations based on sample data.

# Importance: Helps validate theories and supports data-driven decisions.

# %% [markdown]
# Q4. Create a hypothesis that states whether the average weight of male college students is greater than
# the average weight of female college students

# %%
# Null Hypothesis (H₀): μ_male ≤ μ_female

# Alternative Hypothesis (H₁): μ_male > μ_female

# %% [markdown]
# Q5. Write a Python script to conduct a hypothesis test on the difference between two population means,
# given a sample from each population

# %%
from scipy.stats import ttest_ind

# Example samples
sample1 = [80, 85, 78, 90, 88]
sample2 = [75, 70, 72, 68, 74]

t_stat, p_val = ttest_ind(sample1, sample2)
print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# T-statistic: 4.727455680310746
# P-value: 0.0014877958421775903

# %% [markdown]
# Q6: Null and Alternative Hypothesis with Examples

# %%
# Null Hypothesis (H₀): No effect or no difference.

# Alternative Hypothesis (H₁): There is an effect or difference.

# Examples:

# H₀: μ = 50, H₁: μ ≠ 50

# H₀: p ≤ 0.05, H₁: p > 0.05

# %% [markdown]
# Q7: Steps in Hypothesis Testing

# %%
# Define null and alternative hypotheses.

# Choose significance level (α).

# Select the appropriate test.

# Calculate test statistic and p-value.

# Make decision: reject or fail to reject H₀.

# Draw conclusion.

# %% [markdown]
# Q8. Define p-value and explain its significance in hypothesis testing

# %%
# P-value: The probability of observing results at least as extreme as those in your sample, assuming H₀ is true.

# Significance: Low p-value (< α) → reject H₀

# %% [markdown]
# Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
# parameter set to 10

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

x = np.linspace(-5, 5, 200)
df = 10
plt.plot(x, t.pdf(x, df), label='df=10')
plt.title("Student's t-distribution (df=10)")
plt.xlabel("t")
plt.ylabel("Density")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two
# random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
from scipy.stats import ttest_ind

# Simulated data
sample1 = np.random.normal(75, 10, 30)
sample2 = np.random.normal(70, 10, 30)

t_stat, p_val = ttest_ind(sample1, sample2)
print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# T-statistic: 2.827031408921087
# P-value: 0.006436773870470466

# %% [markdown]
# Q11: What is Student’s t distribution? When to use the t-Distribution

# %%
# A probability distribution used when:

# Sample size is small

# Population standard deviation is unknown

# Use it instead of normal distribution when n < 30.

# %% [markdown]
# Q12: What is t-statistic? Formula

# %%
# Used to compare sample mean to population mean or between two samples.


# t = (sample_mean - population_mean) / (sample_std / sqrt(sample_size))

# %% [markdown]
# Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
# sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50.
# Estimate the population mean revenue with a 95% confidence interval

# %%
import scipy.stats as stats

sample_mean = 500
std_dev = 50
n = 50
confidence = 0.95

z = stats.norm.ppf(1 - (1 - confidence)/2)
margin = z * (std_dev / np.sqrt(n))
lower = sample_mean - margin
upper = sample_mean + margin

print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# 95% Confidence Interval: (486.14, 513.86)

# %% [markdown]
# Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a
# clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a
# standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %%
sample_mean = 8
hyp_mean = 10
std_dev = 3
n = 100
alpha = 0.05

t_stat = (sample_mean - hyp_mean) / (std_dev / np.sqrt(n))
p_val = stats.t.sf(np.abs(t_stat), df=n-1) * 2

print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# T-statistic: -6.666666666666667
# P-value: 1.5012289009970215e-09

# %% [markdown]
# Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a
# standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight
# is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5
# pounds with a significance level of 0.01.

# %%
sample_mean = 4.8
hyp_mean = 5
std_dev = 0.5
n = 25
alpha = 0.01

t_stat = (sample_mean - hyp_mean) / (std_dev / np.sqrt(n))
p_val = stats.t.cdf(t_stat, df=n-1)  # left-tailed

print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# T-statistic: -2.0000000000000018
# P-value: 0.02846992496829572

# %% [markdown]
# Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 =
# 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.

# %%
n1, mean1, std1 = 30, 80, 10
n2, mean2, std2 = 40, 75, 8

se = np.sqrt((std1**2/n1) + (std2**2/n2))
t_stat = (mean1 - mean2) / se
df = min(n1-1, n2-1)
p_val = stats.t.sf(np.abs(t_stat), df=df) * 2

print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# T-statistic: 2.2511258444537408
# P-value: 0.0321269365995288

# %% [markdown]
# Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV
# program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard
# deviation of 1.5. Estimate the population mean with a 99% confidence interval

# %%
mean = 4
std = 1.5
n = 50
confidence = 0.99

z = stats.norm.ppf(1 - (1 - confidence)/2)
margin = z * (std / np.sqrt(n))
lower = mean - margin
upper = mean + margin

print(f"99% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# 99% Confidence Interval: (3.45, 4.55)
